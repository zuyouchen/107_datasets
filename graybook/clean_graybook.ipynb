# %% [markdown]
# # Cleaning Graybook.CSV

# %%
import pandas as pd 
df = pd.read_csv('graybook-sp23.csv')
df
# Out:
#                 Employee Name                    Job Title Tenure Empl Class  \
# 0       Gerstenecker, David G          DIR OF INFO TECHNOL    NaN         BA
# 1         Henry, Joshua Keith       ASSOC DIR INFO TECHNOL    NaN         BA
# 2             Meyer, Donald L             SR NETWORK ANLYS    NaN         BA
# 3             Schwartz, Sarah                   COMM COORD    NaN         BA
# 4       Winter-Nelson, Alex E                    DIR, ADMI    NaN         BA
# ...                       ...                          ...    ...        ...
# 14566  Guerra Perez, Gioconda      EXEC ASSOC VC FOR DVSTY    NaN         BA
# 14567    Rand, Jacki Thompson      ASSOC VC NATIVE AFFAIRS    NaN         BA
# 14568    Rand, Jacki Thompson  Employee Total for All Jobs    NaN        NaN
# 14569    VanDuyne, Adam Jareb          EXEC DIR FIN & ADMN    NaN         BA
# 14570        Wantland, Ross A      DIR OF CURR DEVL & EDUC    NaN         BA
#
#        Present FTE  Proposed FTE  Present Salary  Proposed Salary  \
# 0              1.0           1.0       106476.00        109670.28
# 1              1.0           1.0        80871.33         83701.83
# 2              1.0           1.0        89558.22         92692.76
# 3              1.0           1.0        50000.00         51750.00
# 4              0.0           0.0        15000.00         15000.00
# ...            ...           ...             ...              ...
# 14566          1.0           1.0       178500.00        187250.00
# 14567          0.0           0.0        47600.00         47600.00
# 14568          1.0           1.0       152600.00        156275.00
# 14569          1.0           1.0       141000.00        147200.00
# 14570          1.0           1.0        94860.00         98860.00
#
#       College Code                   College Name  Department Code  \
# 0               KL   Agr, Consumer & Env Sciences              348
# 1               KL   Agr, Consumer & Env Sciences              348
# 2               KL   Agr, Consumer & Env Sciences              348
# 3               KL   Agr, Consumer & Env Sciences              521
# 4               KL   Agr, Consumer & Env Sciences              521
# ...            ...                            ...              ...
# 14566           NV  Vice Chancellor for Diversity              594
# 14567           NV  Vice Chancellor for Diversity              594
# 14568           NV  Vice Chancellor for Diversity              594
# 14569           NV  Vice Chancellor for Diversity              594
# 14570           NV  Vice Chancellor for Diversity              594
#
#                      Department Name
# 0           ACES Technology Services
# 1           ACES Technology Services
# 2           ACES Technology Services
# 3              ADM Institute for PHL
# 4              ADM Institute for PHL
# ...                              ...
# 14566  Vice Chancellor for Diversity
# 14567  Vice Chancellor for Diversity
# 14568  Vice Chancellor for Diversity
# 14569  Vice Chancellor for Diversity
# 14570  Vice Chancellor for Diversity
#
# [14571 rows x 12 columns]

# %%
# Get a list of all the columns in the DataFrame
cols = list(df.columns)

# Create a new DataFrame to store the aggregated data
agg_df = pd.DataFrame(columns=cols + ["Job Titles", "Employee Classes"])

# Loop over the unique values of the "Employee Name" column
for name in df["Employee Name"].unique():
    # Filter out the rows for the current name
    name_df = df[df["Employee Name"] == name]
    
    # Get the row w/ Job Total
    total_row = name_df[name_df["Job Title"] == "Employee Total for All Jobs"]
    
    # Use Job Total Row if exists
    if not total_row.empty:
        row = total_row.iloc[0]
    else:
        # If not, use the values from the first row
        row = name_df.iloc[0]
    
    # Get the job titles and employee classes for the current name
    job_titles = list(name_df[name_df["Job Title"] != "Employee Total for All Jobs"]["Job Title"])
    employee_classes = list(name_df[name_df["Job Title"] != "Employee Total for All Jobs"]["Empl Class"])
    
    # Append the aggregated data for the current name to the agg_df DataFrame
    new_row = pd.Series(list(row) + [job_titles, employee_classes], index=cols + ["Job Titles", "Employee Classes"])
    agg_df = agg_df.append(new_row, ignore_index=True)

# %%
agg_df
# Out:
#                Employee Name                    Job Title Tenure Empl Class  \
# 0      Gerstenecker, David G          DIR OF INFO TECHNOL    NaN         BA
# 1        Henry, Joshua Keith       ASSOC DIR INFO TECHNOL    NaN         BA
# 2            Meyer, Donald L             SR NETWORK ANLYS    NaN         BA
# 3            Schwartz, Sarah                   COMM COORD    NaN         BA
# 4      Winter-Nelson, Alex E  Employee Total for All Jobs    NaN        NaN
# ...                      ...                          ...    ...        ...
# 6212       Chambers, Sonya L  EXEC DIR STRATG INITIATIVES    NaN         BA
# 6213         Garrick, Sean C  Employee Total for All Jobs    NaN        NaN
# 6214  Guerra Perez, Gioconda      EXEC ASSOC VC FOR DVSTY    NaN         BA
# 6215    VanDuyne, Adam Jareb          EXEC DIR FIN & ADMN    NaN         BA
# 6216        Wantland, Ross A      DIR OF CURR DEVL & EDUC    NaN         BA
#
#       Present FTE  Proposed FTE  Present Salary  Proposed Salary College Code  \
# 0             1.0           1.0       106476.00        109670.28           KL
# 1             1.0           1.0        80871.33         83701.83           KL
# 2             1.0           1.0        89558.22         92692.76           KL
# 3             1.0           1.0        50000.00         51750.00           KL
# 4             1.0           1.0       186666.00        193532.64           KL
# ...           ...           ...             ...              ...          ...
# 6212          1.0           1.0       163200.00        169500.00           NV
# 6213          1.0           1.0       338248.98        351778.94           NV
# 6214          1.0           1.0       178500.00        187250.00           NV
# 6215          1.0           1.0       141000.00        147200.00           NV
# 6216          1.0           1.0        94860.00         98860.00           NV
#
#                        College Name Department Code  \
# 0      Agr, Consumer & Env Sciences             348
# 1      Agr, Consumer & Env Sciences             348
# 2      Agr, Consumer & Env Sciences             348
# 3      Agr, Consumer & Env Sciences             521
# 4      Agr, Consumer & Env Sciences             521
# ...                             ...             ...
# 6212  Vice Chancellor for Diversity             594
# 6213  Vice Chancellor for Diversity             594
# 6214  Vice Chancellor for Diversity             594
# 6215  Vice Chancellor for Diversity             594
# 6216  Vice Chancellor for Diversity             594
#
#                     Department Name  \
# 0          ACES Technology Services
# 1          ACES Technology Services
# 2          ACES Technology Services
# 3             ADM Institute for PHL
# 4             ADM Institute for PHL
# ...                             ...
# 6212  Vice Chancellor for Diversity
# 6213  Vice Chancellor for Diversity
# 6214  Vice Chancellor for Diversity
# 6215  Vice Chancellor for Diversity
# 6216  Vice Chancellor for Diversity
#
#                                              Job Titles      Employee Classes
# 0                                 [DIR OF INFO TECHNOL]                  [BA]
# 1                              [ASSOC DIR INFO TECHNOL]                  [BA]
# 2                                    [SR NETWORK ANLYS]                  [BA]
# 3                                          [COMM COORD]                  [BA]
# 4     [DIR, ADMI, PROF, ASSOC DEAN FOR INATL PRGMS, ...  [BA, AA, BA, AA, AA]
# ...                                                 ...                   ...
# 6212                      [EXEC DIR STRATG INITIATIVES]                  [BA]
# 6213  [VC FOR DVSTY, EQUITY & INCL, VC FOR DVSTY, EQ...              [BA, BA]
# 6214                          [EXEC ASSOC VC FOR DVSTY]                  [BA]
# 6215                              [EXEC DIR FIN & ADMN]                  [BA]
# 6216                          [DIR OF CURR DEVL & EDUC]                  [BA]
#
# [6217 rows x 14 columns]

# %%
for i, row in agg_df.iterrows():
    # Replace the "Job Title" column with the first item of the list in the "Job Titles" column
    agg_df.at[i, "Job Title"] = row["Job Titles"][0]
    # Remove duplicates in the "Job Titles" column
    agg_df.at[i, "Job Titles"] = list(set(row["Job Titles"]))
    # Remove duplicates in the "Employee Classes" column
    agg_df.at[i, "Employee Classes"] = list(set(row["Employee Classes"]))
    
agg_df
# Out:
#                Employee Name                    Job Title Tenure Empl Class  \
# 0      Gerstenecker, David G          DIR OF INFO TECHNOL    NaN         BA
# 1        Henry, Joshua Keith       ASSOC DIR INFO TECHNOL    NaN         BA
# 2            Meyer, Donald L             SR NETWORK ANLYS    NaN         BA
# 3            Schwartz, Sarah                   COMM COORD    NaN         BA
# 4      Winter-Nelson, Alex E                    DIR, ADMI    NaN        NaN
# ...                      ...                          ...    ...        ...
# 6212       Chambers, Sonya L  EXEC DIR STRATG INITIATIVES    NaN         BA
# 6213         Garrick, Sean C  VC FOR DVSTY, EQUITY & INCL    NaN        NaN
# 6214  Guerra Perez, Gioconda      EXEC ASSOC VC FOR DVSTY    NaN         BA
# 6215    VanDuyne, Adam Jareb          EXEC DIR FIN & ADMN    NaN         BA
# 6216        Wantland, Ross A      DIR OF CURR DEVL & EDUC    NaN         BA
#
#       Present FTE  Proposed FTE  Present Salary  Proposed Salary College Code  \
# 0             1.0           1.0       106476.00        109670.28           KL
# 1             1.0           1.0        80871.33         83701.83           KL
# 2             1.0           1.0        89558.22         92692.76           KL
# 3             1.0           1.0        50000.00         51750.00           KL
# 4             1.0           1.0       186666.00        193532.64           KL
# ...           ...           ...             ...              ...          ...
# 6212          1.0           1.0       163200.00        169500.00           NV
# 6213          1.0           1.0       338248.98        351778.94           NV
# 6214          1.0           1.0       178500.00        187250.00           NV
# 6215          1.0           1.0       141000.00        147200.00           NV
# 6216          1.0           1.0        94860.00         98860.00           NV
#
#                        College Name Department Code  \
# 0      Agr, Consumer & Env Sciences             348
# 1      Agr, Consumer & Env Sciences             348
# 2      Agr, Consumer & Env Sciences             348
# 3      Agr, Consumer & Env Sciences             521
# 4      Agr, Consumer & Env Sciences             521
# ...                             ...             ...
# 6212  Vice Chancellor for Diversity             594
# 6213  Vice Chancellor for Diversity             594
# 6214  Vice Chancellor for Diversity             594
# 6215  Vice Chancellor for Diversity             594
# 6216  Vice Chancellor for Diversity             594
#
#                     Department Name  \
# 0          ACES Technology Services
# 1          ACES Technology Services
# 2          ACES Technology Services
# 3             ADM Institute for PHL
# 4             ADM Institute for PHL
# ...                             ...
# 6212  Vice Chancellor for Diversity
# 6213  Vice Chancellor for Diversity
# 6214  Vice Chancellor for Diversity
# 6215  Vice Chancellor for Diversity
# 6216  Vice Chancellor for Diversity
#
#                                          Job Titles Employee Classes
# 0                             [DIR OF INFO TECHNOL]             [BA]
# 1                          [ASSOC DIR INFO TECHNOL]             [BA]
# 2                                [SR NETWORK ANLYS]             [BA]
# 3                                      [COMM COORD]             [BA]
# 4     [PROF, ASSOC DEAN FOR INATL PRGMS, DIR, ADMI]         [AA, BA]
# ...                                             ...              ...
# 6212                  [EXEC DIR STRATG INITIATIVES]             [BA]
# 6213                  [VC FOR DVSTY, EQUITY & INCL]             [BA]
# 6214                      [EXEC ASSOC VC FOR DVSTY]             [BA]
# 6215                          [EXEC DIR FIN & ADMN]             [BA]
# 6216                      [DIR OF CURR DEVL & EDUC]             [BA]
#
# [6217 rows x 14 columns]

# %%
agg_df.to_csv('graybook-clean-sp23.csv', index=False)
